# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
def csv_downloader(URL:str, name:str, path:str)->pd.DataFrame:
    df = pd.read_csv(URL)
    df.to_csv(f'{path}/{name}.csv', index = False)
    print(f'The {name}.csv was successfully stored in {path}')
    return df

# %%
df.head()
# Out:
#            customer_id  order_date  revenue
# 0  Mr. Brion Stark Sr.  2004-12-20       32
# 1       Ethyl Botsford  2005-05-02       36
# 2       Hosteen Jacobi  2004-03-06      116
# 3        Mr. Edw Frami  2006-03-15       99
# 4          Josef Lemke  2006-08-14       76

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4906 entries, 0 to 4905
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  4906 non-null   str
#  1   order_date   4906 non-null   str
#  2   revenue      4906 non-null   int64
# dtypes: int64(1), str(2)
# memory usage: 237.5 KB

# %%
df.describe()
# Out:
#            revenue
# count  4906.000000
# mean     94.610273
# std      57.827010
# min      10.000000
# 25%      45.000000
# 50%      81.000000
# 75%     137.000000
# max     219.000000

# %%
df.columns
# Out:
# Index(['customer_id', 'order_date', 'revenue'], dtype='str')

# %%
URL = 'https://raw.githubusercontent.com/hovhannisyan91/data_analytics_with_python/refs/heads/main/data/rfm/orders.csv'
df = pd.read_csv(URL)

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

pd.set_option('display.max_columns', None)
px.defaults.template = "plotly_white"

# %%
orders = pd.read_csv('../data/rfm/orders.csv', parse_dates=['order_date'])
orders.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 orders = pd.read_csv('../data/rfm/orders.csv', parse_dates=['order_date'])
#       2 orders.head()
#
# NameError: name 'pd' is not defined

# %%
fig = px.histogram(
    orders,
    x='revenue',
    nbins=30,
    title='Histogram of Revenue'
)

fig.update_layout(
    xaxis_title='Revenue',
    yaxis_title='Count'
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 fig = px.histogram(
#       2     orders,
#       3     x='revenue',
#       4     nbins=30,
#       5     title='Histogram of Revenue'
#       6 )
#       8 fig.update_layout(
#       9     xaxis_title='Revenue',
#      10     yaxis_title='Count'
#      11 )
#      13 fig.show()
#
# NameError: name 'px' is not defined
