# %% [markdown]
# ## Dates

# %%
from datetime import datetime, date, timedelta

# %%
my_date = date(year=2025,month=3,day=24)

# %%
type(my_date)
# Out:
# datetime.date

# %%
my_time = datetime(year=2025,month=3,day=24, hour=14,minute=59,second=58)

# %%
my_time
# Out:
# datetime.datetime(2025, 3, 24, 14, 59, 58)

# %%
today = date.today()
today
# Out:
# datetime.date(2026, 3, 24)

# %%
now = datetime.now()
now
# Out:
# datetime.datetime(2026, 3, 24, 22, 12, 34, 209600)

# %%
my_date.strftime("%Y/%m/%d")
# Out:
# '2025/03/24'

# %%
my_date.strftime("%Y-%m-%d")
# Out:
# '2025-03-24'

# %%
my_date.strftime("%b %d %y")
# Out:
# 'Mar 24 25'

# %%
my_date
# Out:
# datetime.date(2025, 3, 24)

# %%
start_date = my_date
end_date = datetime(2026,4,4)

# %%
delta = end_date -  start_date
delta
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 delta = end_date -  start_date
#       2 delta
#
# TypeError: unsupported operand type(s) for -: 'datetime.datetime' and 'datetime.date'

# %%
rd = (today + timedelta(days=5)).strftime("%b %d %y")
rd
# Out:
# 'Mar 29 26'

# %% [markdown]
# ### Dates with Pandas

# %%
import pandas as pd

df_dates = pd.DataFrame({
    "customer_id": [101, 102, 103, 104, 105],
    "signup_date": ["2024-01-15", "2024-02-20", "2024-03-05", "2024-03-18", "2024-04-10"],
    "last_purchase": ["2024-06-01", "2024-06-15", "2024-07-01", "2024-07-08", "2024-07-12"]
})

df_dates
# Out:
#    customer_id signup_date last_purchase
# 0          101  2024-01-15    2024-06-01
# 1          102  2024-02-20    2024-06-15
# 2          103  2024-03-05    2024-07-01
# 3          104  2024-03-18    2024-07-08
# 4          105  2024-04-10    2024-07-12

# %%
df_dates.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    5 non-null      int64
#  1   signup_date    5 non-null      str
#  2   last_purchase  5 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 352.0 bytes

# %%
df_dates['signup_date'] = pd.to_datetime(df_dates['signup_date'])
df_dates['last_purchase'] = pd.to_datetime(df_dates['last_purchase'])

# %%
df_dates.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    5 non-null      int64
#  1   signup_date    5 non-null      datetime64[us]
#  2   last_purchase  5 non-null      datetime64[us]
# dtypes: datetime64[us](2), int64(1)
# memory usage: 252.0 bytes

# %%
df_dates.to_csv('../data/test.csv', index=False)

# %%
test = pd.read_csv('../data/test.csv',parse_dates=['signup_date'
                                                   ])

# %%
df_dates.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    5 non-null      int64
#  1   signup_date    5 non-null      datetime64[us]
#  2   last_purchase  5 non-null      datetime64[us]
# dtypes: datetime64[us](2), int64(1)
# memory usage: 252.0 bytes

# %%
df_dates["signup_year"] = df_dates["signup_date"].dt.is_year
df_dates["signup_year"] = df_dates["signup_date"].dt.is_month
df_dates["signup_year"] = df_dates["signup_date"].dt.is_day
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df_dates["signup_year"] = df_dates["signup_date"].dt.is_year
#       2 df_dates["signup_year"] = df_dates["signup_date"].dt.is_month
#       3 df_dates["signup_year"] = df_dates["signup_date"].dt.is_day
#
# AttributeError: 'DatetimeProperties' object has no attribute 'is_year'

# %%
df_dates["signup_month_name"] = df_dates["signup_date"].dt.month_name()

# %%
df_dates
# Out:
#    customer_id signup_date last_purchase  signup_year signup_month_name
# 0          101  2024-01-15    2024-06-01        False           January
# 1          102  2024-02-20    2024-06-15        False          February
# 2          103  2024-03-05    2024-07-01        False             March
# 3          104  2024-03-18    2024-07-08        False             March
# 4          105  2024-04-10    2024-07-12        False             April

# %%
import pandas as pd
import numpy as np
import plotly.express as px

np.random.seed(42)
px.defaults.template = "plotly_white"

months = pd.date_range("2024-01-01", periods=6, freq="MS")
regions = ["North", "South", "East"]
products = ["A", "B"]

rows = []

for month in months:
    for region in regions:
        for product in products:
            sales = np.random.randint(80, 220)
            customers = np.random.randint(20, 90)
            units = np.random.randint(10, 70)
            
            rows.append([month, region, product, sales, customers, units])

df_plotly = pd.DataFrame(
    rows,
    columns=["month", "region", "product", "sales", "customers", "units"]
)

df_plotly["month_name"] = df_plotly["month"].dt.strftime("%b")
df_plotly.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[41], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import plotly.express as px
#       5 np.random.seed(42)
#       6 px.defaults.template = "plotly_white"
#
# ModuleNotFoundError: No module named 'plotly'
