# %%
from templates import *
from templates import my_bar_plot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 from templates import *
# ----> 2 from templates import my_bar_plot
#
# ImportError: cannot import name 'my_bar_plot' from 'templates' (c:\Users\user\Desktop\ACA\data_analytics_with_python\notebooks\templates.py)
